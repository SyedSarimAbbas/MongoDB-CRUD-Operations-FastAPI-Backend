# %% [markdown]
# # MongoDB-Aggregations

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

username = "Your User Name Here"
password = quote_plus("Your Password Here")
dbName = "stocks_data"

uri = f"mongodb+srv://{username}:{password}@cluster0.wzr6r9y.mongodb.net/{dbName}?retryWrites=true&w=majority"
client = MongoClient(uri, tls=True, tlsAllowInvalidCertificates=True)
db = client[dbName]
stocks_collection = db["stocks_data_collection"]

print(" Connected to MongoDB Atlas successfully!",client.server_info())
# Insert a test stock
stock = {"symbol": "AAPL", "id": "1", "price": 150}
stocks_collection.insert_one(stock)
print("Stock inserted successfully!")
# Out:
#  Connected to MongoDB Atlas successfully! {'version': '8.0.19', 'gitVersion': 'cc1adb6b0875cc3003854ac2489818e459686f0b', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 19, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1771338179, 2), 'signature': {'hash': b'\xa0\xcd;}#XEX\xdb\xcf\xad(z\xd9\xeb\x07\xd0 \x89\x19', 'keyId': 7549286612002144258}}, 'operationTime': Timestamp(1771338179, 2)}
# Stock inserted successfully!
